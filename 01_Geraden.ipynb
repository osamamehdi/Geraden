# %% [markdown]
# # Geradengleichungen

# %% [markdown]
# Allgemeine Formel $y = m * x + t$

# %% [markdown]
# Dabei steht m für die **Steigung** der Geraden.
#
# Der **y-Achsenabschnitt t**, gibt an welchen Wert die Gerade für **$ x = 0 $** hat.

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Folgendes Beispiel beschreibt eine einfache Gerade.
#
# Die Variablen $m$, $x$ und $t$ sind Teil der Geradengleichung.
#
# Für $t = 0$ entsteht eine Gleichung mit der Form $y = m*x$. Geraden mit dieser Form verlaufen durch den
# Ursprung $ O (0|0)$ und werden **Ursprungsgeraden** genannt.

# %%
import matplotlib.pyplot as plt

xs = []
ys_1 = []

m_1 = 1
t_1 = 0

for x in range(0, 3):
    xs.append(x)
    ys_1.append((m_1 * x) + t_1)
    
plt.plot(xs, ys_1, "r-") # Rote Gerade
plt.grid(True)
plt.show()

# %% [markdown]
# ## Steigung

# %% [markdown]
# Die Variable **"m"** beschreibt die Steigung der Gerade. Diese lässt sich mit der Formel
#
# $m = \frac{y_2 - y_1}{x_2 - x_1}$
#
# berechnen.

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Folgender Code beschreibt eine Gerade.
#
# **m_1** steht für die Steigung der Geraden.
#
# Anhand der unten eingeblendeten Gerade erkennst du, wie sich die Steigung auf die Geraden auswirkt.
#
# ## Aufgabe
#
# Überprüfe durch ändern der Variable **m_1** im Code wie sich die Steigung der Gerade verändert.
#
# Ändere die Variable im Code ab, so dass sie die Gerade $y = 3x$ darstellen.
#
# Drücke auf "Run" drückst (oben in der Mitte), um die Änderungen anzuwenden.
#
# <span style='color:red'> **Beachte! Wenn du die Werte veränderst, können sich die x- und y-Achse verschieben!** </span>

# %%
import matplotlib.pyplot as plt

xs = []
ys_1 = []
ys_2 = []

m_1 = 1
t_1 = 0

for x in range(-2, 3):
    xs.append(x) 
    ys_1.append((m_1 * x) + t_1)
    
plt.plot(xs, ys_1, "r-") # Rote Gerade = y
plt.grid(True)
plt.show()

# %% [markdown]
# ## y-Achsenabschnitt "t"

# %% [markdown]
# Die bisher behandelten Geraden waren Ursprungsgeraden. Diese gehen immer durch den Nullpunkt (0|0) und haben somit den Wert 0 für t

# %% [markdown]
# Die Variable t in der Formel $y = m * x + t$ beschreibt die Verschiebung der Gerade an der y-Achse. Wird ein Wert der größer als 0 für $t$ ist angegeben, verschiebt sich die Gerade nach oben. Ist der $t$ kleiner als 0 verschiebt sie sich nach unten.

# %% [markdown]
# ## Beispiel

# %% [markdown]
# Folgender Code beschreibt eine Gerade.
#
# Verändere die Werte der Variablen t_1.
#
# Anhand der sich verändernden y-Werte bei x = 0 erkennst du, wie die Geraden im Koordinatensystem verschoben werden.
#
#
# ## Aufgabe
#
# Überprüfe durch ändern der Variable **t_1** im Code wie sich der y-Achsenabschnitt t der Gerade verändert.
#
# Ändere die Variablen im Code ab, so dass sie die Gerade $y = 3x + 1$ darstellen.
#
# Drücke auf "Run" drückst (oben in der Mitte), um die Änderungen anzuwenden.
#
# <span style='color:red'> **Beachte! Wenn du die Werte veränderst, können sich die x- und y-Achse verschieben!** </span>

# %%
import matplotlib.pyplot as plt

xs = []
ys_1 = []

m_1 = 1
t_1 = 2

for x in range(-2, 3):
    xs.append(x) 
    ys_1.append((m_1 * x) + t_1)
    
plt.plot(xs, ys_1, "r-") # Rote Gerade = y
plt.grid(True)
plt.show()

# %% [markdown]
# ## Weitere Aufgaben zu Ursprungsgeraden und Geraden der Form $y = mx + t$ findest du im Buch auf Seite 24, Aufgabe 5, 6 und 7 sowie auf Seite 27, Aufgabe 4!
